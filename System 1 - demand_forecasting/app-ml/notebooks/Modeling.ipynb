# %%
import os
import sys
from pathlib import Path

# Dynamically locate project root and set working dir
project_root = Path().resolve().parents[1]
os.chdir(project_root)
sys.path.append(str(project_root))

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
from catboost import CatBoostRegressor, Pool
import optuna
from typing import Union, Dict, Tuple
from sklearn.model_selection import TimeSeriesSplit
from ydata_profiling import ProfileReport
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.ensemble import RandomForestRegressor as RF
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# # Table of Contents
# - [Dataset Preparation](#Dataset-Preparation)
# - [Baseline Model](#Baseline-Model)
# - [Baseline Model with target lag features](#Baseline-Model-with-Target-Lag-Features)
# - [Baseline Model with all lag features](#Baseline-Model-with-All-Lag-Features)
# - [Gradient Boosting with Hyperparameters Tuning](#Gradient-Boosting-with-Hyperparameters-Tuning)
# - [Conclusions](#Conclusions)

# %% [markdown]
# # Preprocessing

# %%
# Loading the data
data = pd.read_parquet('./data/raw_data/raw_data_full.parquet')

# %%
data.head(3)
# Out:
#               datetime  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0  2011-01-01 00:00:00       1   0     1   0        0        6           0
# 1  2011-01-01 01:00:00       1   0     1   1        0        6           0
# 2  2011-01-01 02:00:00       1   0     1   2        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32

# %% [markdown]
# Let's drop the columns that are not required for further analysis and modeling.
#
# - 'yr' does not seem to help because it
# - 'casual', 'registered' are already included in the target column 'cnt'

# %%
drop_cols = ['yr', 'casual', 'registered', 'datetime']

# %%
data = data.drop(columns=drop_cols)

# %%
data.head(3)
# Out:
#    season  mnth  hr  holiday  weekday  workingday  weathersit  temp   atemp  \
# 0       1     1   0        0        6           0           1  0.24  0.2879
# 1       1     1   1        0        6           0           1  0.22  0.2727
# 2       1     1   2        0        6           0           1  0.22  0.2727
#
#     hum  windspeed  cnt
# 0  0.81        0.0   16
# 1  0.80        0.0   40
# 2  0.80        0.0   32

# %% [markdown]
# # Baseline Model

# %% [markdown]
# We will use Random Forest using Raw Features as the Baseline Model because it does not require much tuning.
#
# Then, we will add features and try other algorithms to see how big the improvement is.
#
# For the metrics, we will use:
# - MAPE
# - MAE
# - RMSE

# %%
def compute_metrics(
    y_true: Union[np.ndarray, list],
    y_pred: Union[np.ndarray, list]
) -> Dict[str, float]:
    """
    Compute evaluation metrics between true and predicted values.

    Metrics returned:
    - MAPE: Mean Absolute Percentage Error (in %)
    - MAE: Mean Absolute Error
    - RMSE: Root Mean Squared Error

    Parameters:
    ----------
    y_true : array-like
        Ground truth values.
    y_pred : array-like
        Predicted values.

    Returns:
    -------
    dict
        Dictionary with keys 'MAPE', 'MAE', and 'RMSE' and their float values.
    """
    mae = mean_absolute_error(y_true, y_pred)
    rmse = mean_squared_error(y_true, y_pred)

    y_true = np.array(y_true)
    y_pred = np.array(y_pred)

    mape = np.mean(np.abs((y_true - y_pred) / np.where(y_true == 0, 0.01, y_true))) * 100

    return {
        'MAE': round(mae, 2),
        'RMSE': round(rmse, 2),
        'MAPE': round(mape, 2)
    }

# %%
def prepare_dataset(
    df: pd.DataFrame,
    train_fraction: float = 0.8
) -> Tuple[pd.DataFrame, pd.DataFrame, pd.Series, pd.Series]:
    """
    Splits a DataFrame into training and testing sets for features and target.

    Parameters:
    ----------
    df : pd.DataFrame
        The input DataFrame that must contain a 'target' column.
    train_fraction : float, optional (default=0.8)
        The fraction of data to use for training (between 0 and 1).

    Returns:
    -------
    x_train : pd.DataFrame
        Training features.
    x_test : pd.DataFrame
        Testing features.
    y_train : pd.Series
        Training target values.
    y_test : pd.Series
        Testing target values.
    """
    feats = [col for col in df.columns if col != 'target']
    x, y = df[feats], df['target']
    train_size = int(train_fraction * df.shape[0])
    x_train, x_test = x[:train_size], x[train_size:]
    y_train, y_test = y[:train_size], y[train_size:]
    return x_train, x_test, y_train, y_test

# %% [markdown]
# #### Target definition
#
# For the target, we will use the next hour bike count because we want to predict what this value will be ti adjust the pricing.

# %% [markdown]
# ## Training

# %%
df = data.copy()

# %%
df['target'] = df['cnt'].shift(-1).fillna(method='ffill')
df.drop(columns=['cnt'], inplace=True)

# %%
x_train, x_test, y_train, y_test = prepare_dataset(df, train_fraction=0.8)

# %%
# %%time
model = RF(n_estimators=100)
model.fit(x_train, y_train)
# Out:
# CPU times: user 6.54 s, sys: 84 ms, total: 6.62 s
# Wall time: 6.65 s
# RandomForestRegressor()

# %% [markdown]
# ## Inference

# %%
y_pred = model.predict(x_test)

# %% [markdown]
# ## Postprocessing

# %%
metrics_base = compute_metrics(y_test.values, y_pred)
metrics_base
# Out:
# {'MAE': 85.33, 'RMSE': 15227.77, 'MAPE': np.float64(38.83)}

# %%
n = 300
plt.plot(y_test.values[:n], label='y_test')
plt.plot(y_pred[:n], label='y_pred')
plt.legend()

# %% [markdown]
# **Observations**
#
# - We see that values below 200 are well predicted
# - We see that the peaks are significantly underpredicted.

# %% [markdown]
# **Dummy model**
#
# A dummy model is the model that tells that the next target value is the same as the previous value.

# %%
y_dummy = y_test.shift(1).fillna(method='bfill')
metrics_dummy = compute_metrics(y_test.values, y_dummy)

# %%
print('Dummy model scores:', metrics_dummy)
print('Baseline model scores:', metrics_base)
# Out:
# Dummy model scores: {'MAE': 85.15, 'RMSE': 16808.16, 'MAPE': np.float64(54.52)}
# Baseline model scores: {'MAE': 85.33, 'RMSE': 15227.77, 'MAPE': np.float64(38.83)}

# %% [markdown]
# We see that our Baseline Model does not do much better that the dummy model
#
# We see that only the MAPE metrics decreased quite well, while the other two are not, especially MAE.
#
# This gives the conclusion that some feature engineering is definteily required.

# %% [markdown]
# # Baseline Model with Target Lag Features

# %% [markdown]
# A good idea is to add the lagged values of the target because we assume it's goona be available by the time we make the predictions for the next hour.
#
# To understand how many lagged features we need, let's compute autocorrelation for the target.

# %%
# Let's compute autocorrelation
for lag in range(1, 25):
    print(f"Lag {lag}: {df['target'].autocorr(lag=lag):.3f}")
# Out:
# Lag 1: 0.844
# Lag 2: 0.594
# Lag 3: 0.404
# Lag 4: 0.272
# Lag 5: 0.146
# Lag 6: 0.010
# Lag 7: -0.093
# Lag 8: -0.113
# Lag 9: -0.058
# Lag 10: -0.054
# Lag 11: -0.107
# Lag 12: -0.140
# Lag 13: -0.114
# Lag 14: -0.064
# Lag 15: -0.060
# Lag 16: -0.093
# Lag 17: -0.063
# Lag 18: 0.036
# Lag 19: 0.156
# Lag 20: 0.265
# Lag 21: 0.373
# Lag 22: 0.522
# Lag 23: 0.710
# Lag 24: 0.816

# %% [markdown]
# We see that the autocrrelations are high for the first and last 3 values that indicates a strong daily seasonality.
#
# Let's add this lags.

# %% [markdown]
# When the model to be run in production, from the pipeline perspective, it's better to have the 'cnt' column back and take the lags relative to it to avoid confusion.

# %% [markdown]
# ## Feature Engineering

# %%
df = data.copy()
df['target'] = df['cnt'].shift(-1).fillna(method='ffill')
df.head(3)
# Out:
#    season  mnth  hr  holiday  weekday  workingday  weathersit  temp   atemp  \
# 0       1     1   0        0        6           0           1  0.24  0.2879
# 1       1     1   1        0        6           0           1  0.22  0.2727
# 2       1     1   2        0        6           0           1  0.22  0.2727
#
#     hum  windspeed  cnt  target
# 0  0.81        0.0   16    40.0
# 1  0.80        0.0   40    32.0
# 2  0.80        0.0   32    13.0

# %% [markdown]
# The 'cnt' column is alread 1 lag behind the target, so we need to make shifts of the 'cnt' column from 1 to 2 and from 22 to 23.

# %%
# Add first 2 lags
for i in range(1, 3):
    df[f'cnt_lag_{i}'] = df['cnt'].shift(i).fillna(method='bfill')

# Add last 2 lags
for i in range(22, 24):
    df[f'cnt_lag_{i}'] = df['cnt'].shift(i).fillna(method='bfill')

# %%
df.head(3)
# Out:
#    season  mnth  hr  holiday  weekday  workingday  weathersit  temp   atemp  \
# 0       1     1   0        0        6           0           1  0.24  0.2879
# 1       1     1   1        0        6           0           1  0.22  0.2727
# 2       1     1   2        0        6           0           1  0.22  0.2727
#
#     hum  windspeed  cnt  target  cnt_lag_1  cnt_lag_2  cnt_lag_22  cnt_lag_23
# 0  0.81        0.0   16    40.0       16.0       16.0        16.0        16.0
# 1  0.80        0.0   40    32.0       16.0       16.0        16.0        16.0
# 2  0.80        0.0   32    13.0       40.0       16.0        16.0        16.0

# %% [markdown]
# ## Training

# %% [markdown]
# Let's see if this helps the model

# %%
x_train, x_test, y_train, y_test = prepare_dataset(df, train_fraction=0.8)

# %%
x_train
# Out:
#        season  mnth  hr  holiday  weekday  workingday  weathersit  temp  \
# 0           1     1   0        0        6           0           1  0.24
# 1           1     1   1        0        6           0           1  0.22
# 2           1     1   2        0        6           0           1  0.22
# 3           1     1   3        0        6           0           1  0.24
# 4           1     1   4        0        6           0           1  0.24
# ...       ...   ...  ..      ...      ...         ...         ...   ...
# 13898       3     8   7        0        2           1           2  0.70
# 13899       3     8   8        0        2           1           2  0.70
# 13900       3     8   9        0        2           1           2  0.70
# 13901       3     8  10        0        2           1           2  0.74
# 13902       3     8  11        0        2           1           2  0.76
#
#         atemp   hum  windspeed  cnt  cnt_lag_1  cnt_lag_2  cnt_lag_22  \
# 0      0.2879  0.81     0.0000   16       16.0       16.0        16.0
# 1      0.2727  0.80     0.0000   40       16.0       16.0        16.0
# 2      0.2727  0.80     0.0000   32       40.0       16.0        16.0
# 3      0.2879  0.75     0.0000   13       32.0       40.0        16.0
# 4      0.2879  0.75     0.0000    1       13.0       32.0        16.0
# ...       ...   ...        ...  ...        ...        ...         ...
# 13898  0.6667  0.74     0.1343  502      179.0       36.0       276.0
# 13899  0.6515  0.70     0.1642  705      502.0      179.0       213.0
# 13900  0.6667  0.74     0.1343  327      705.0      502.0       260.0
# 13901  0.6970  0.70     0.1343  250      327.0      705.0       285.0
# 13902  0.7273  0.66     0.0896  214      250.0      327.0       289.0
#
#        cnt_lag_23
# 0            16.0
# 1            16.0
# 2            16.0
# 3            16.0
# 4            16.0
# ...           ...
# 13898       605.0
# 13899       276.0
# 13900       213.0
# 13901       260.0
# 13902       285.0
#
# [13903 rows x 16 columns]

# %%
model = RF(n_estimators=100)
model.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# ## Inference

# %%
y_pred = model.predict(x_test)

# %% [markdown]
# ## Postprocessing

# %%
metrics_target_lag = compute_metrics(y_test.values, y_pred)
metrics_target_lag
# Out:
# {'MAE': 32.34, 'RMSE': 3019.01, 'MAPE': np.float64(22.64)}

# %%
print('Baseline model scores:', metrics_base)
print('Baseline model with target lags scores:', metrics_target_lag)
# Out:
# Baseline model scores: {'MAE': 85.33, 'RMSE': 15227.77, 'MAPE': np.float64(38.83)}
# Baseline model with target lags scores: {'MAE': 32.34, 'RMSE': 3019.01, 'MAPE': np.float64(22.64)}

# %%
n = 300
plt.plot(y_test.values[:n], label='y_test')
plt.plot(y_pred[:n], label='y_pred')
plt.legend()

# %% [markdown]
# Now we see a significant imporvement.
#
# We clearly see that the peaks now are better captured.

# %% [markdown]
# # Baseline Model with All Lag Features

# %% [markdown]
# Let's add the lag features for other features, not only for the target.
#
# We will add only the first 3 lags, you can experiment with different lags and see the performance

# %%
df.columns
# Out:
# Index(['season', 'mnth', 'hr', 'holiday', 'weekday', 'workingday',
#        'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'cnt', 'target',
#        'cnt_lag_1', 'cnt_lag_2', 'cnt_lag_22', 'cnt_lag_23'],
#       dtype='object')

# %% [markdown]
# ## Feature Engineering

# %%
lag_feats = ['hr', 'weekday', 'weathersit', 'temp', 'hum']

n = 3
for feat in lag_feats:
    for i in range(1, n+1):
        df[f'{feat}_lag_{i}'] = df[feat].shift(i).fillna(method='bfill')

# %% [markdown]
# ## Training

# %%
x_train, x_test, y_train, y_test = prepare_dataset(df, train_fraction=0.8)

# %%
x_train.head(3)
# Out:
#    season  mnth  hr  holiday  weekday  workingday  weathersit  temp   atemp  \
# 0       1     1   0        0        6           0           1  0.24  0.2879
# 1       1     1   1        0        6           0           1  0.22  0.2727
# 2       1     1   2        0        6           0           1  0.22  0.2727
#
#     hum  ...  weekday_lag_3  weathersit_lag_1  weathersit_lag_2  \
# 0  0.81  ...            6.0               1.0               1.0
# 1  0.80  ...            6.0               1.0               1.0
# 2  0.80  ...            6.0               1.0               1.0
#
#    weathersit_lag_3  temp_lag_1  temp_lag_2  temp_lag_3  hum_lag_1  hum_lag_2  \
# 0               1.0        0.24        0.24        0.24       0.81       0.81
# 1               1.0        0.24        0.24        0.24       0.81       0.81
# 2               1.0        0.22        0.24        0.24       0.80       0.81
#
#    hum_lag_3
# 0       0.81
# 1       0.81
# 2       0.81
#
# [3 rows x 31 columns]

# %%
x_train.columns
# Out:
# Index(['season', 'mnth', 'hr', 'holiday', 'weekday', 'workingday',
#        'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'cnt', 'cnt_lag_1',
#        'cnt_lag_2', 'cnt_lag_22', 'cnt_lag_23', 'hr_lag_1', 'hr_lag_2',
#        'hr_lag_3', 'weekday_lag_1', 'weekday_lag_2', 'weekday_lag_3',
#        'weathersit_lag_1', 'weathersit_lag_2', 'weathersit_lag_3',
#        'temp_lag_1', 'temp_lag_2', 'temp_lag_3', 'hum_lag_1', 'hum_lag_2',
#        'hum_lag_3'],
#       dtype='object')

# %%
# %%time
np.random.seed(23)
model = RF(n_estimators=100, verbose=1)
model.fit(x_train, y_train)
# Out:
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:   13.7s
# CPU times: user 27.8 s, sys: 85.5 ms, total: 27.9 s
# Wall time: 28.7 s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:   28.6s finished
# RandomForestRegressor(verbose=1)

# %% [markdown]
# ## Inference

# %%
y_pred = model.predict(x_test)
# Out:
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.1s finished

# %% [markdown]
# # Postprocessing

# %%
metrics_all_lags = compute_metrics(y_test.values, y_pred)
metrics_all_lags
# Out:
# {'MAE': 32.3, 'RMSE': 3039.02, 'MAPE': np.float64(22.36)}

# %%
print('Baseline model scores:', metrics_base)
print('Baseline model with target lags scores:', metrics_target_lag)
print('Baseline model with all lags scores:', metrics_all_lags)
# Out:
# Baseline model scores: {'MAE': 85.33, 'RMSE': 15227.77, 'MAPE': np.float64(38.83)}
# Baseline model with target lags scores: {'MAE': 32.34, 'RMSE': 3019.01, 'MAPE': np.float64(22.64)}
# Baseline model with all lags scores: {'MAE': 32.3, 'RMSE': 3039.02, 'MAPE': np.float64(22.36)}

# %% [markdown]
# We see that adding the feature lags futher improved the performance, but the improvement is not that big as before.
#
# However, with some basic feature engineering we still able to improve the scores and this we can add to the final production pipeline.

# %% [markdown]
# # Gradient Boosting with Hyperparameters Tuning

# %% [markdown]
# ## Training

# %%
df.reset_index(drop=True, inplace=True)

# %%
x_train, x_test, y_train, y_test = prepare_dataset(df, train_fraction=0.8)

# %%
x_train
# Out:
#        season  mnth  hr  holiday  weekday  workingday  weathersit  temp  \
# 0           1     1   0        0        6           0           1  0.24
# 1           1     1   1        0        6           0           1  0.22
# 2           1     1   2        0        6           0           1  0.22
# 3           1     1   3        0        6           0           1  0.24
# 4           1     1   4        0        6           0           1  0.24
# ...       ...   ...  ..      ...      ...         ...         ...   ...
# 13898       3     8   7        0        2           1           2  0.70
# 13899       3     8   8        0        2           1           2  0.70
# 13900       3     8   9        0        2           1           2  0.70
# 13901       3     8  10        0        2           1           2  0.74
# 13902       3     8  11        0        2           1           2  0.76
#
#         atemp   hum  ...  weekday_lag_3  weathersit_lag_1  weathersit_lag_2  \
# 0      0.2879  0.81  ...            6.0               1.0               1.0
# 1      0.2727  0.80  ...            6.0               1.0               1.0
# 2      0.2727  0.80  ...            6.0               1.0               1.0
# 3      0.2879  0.75  ...            6.0               1.0               1.0
# 4      0.2879  0.75  ...            6.0               1.0               1.0
# ...       ...   ...  ...            ...               ...               ...
# 13898  0.6667  0.74  ...            2.0               2.0               1.0
# 13899  0.6515  0.70  ...            2.0               2.0               2.0
# 13900  0.6667  0.74  ...            2.0               2.0               2.0
# 13901  0.6970  0.70  ...            2.0               2.0               2.0
# 13902  0.7273  0.66  ...            2.0               2.0               2.0
#
#        weathersit_lag_3  temp_lag_1  temp_lag_2  temp_lag_3  hum_lag_1  \
# 0                   1.0        0.24        0.24        0.24       0.81
# 1                   1.0        0.24        0.24        0.24       0.81
# 2                   1.0        0.22        0.24        0.24       0.80
# 3                   1.0        0.22        0.22        0.24       0.80
# 4                   1.0        0.24        0.22        0.22       0.75
# ...                 ...         ...         ...         ...        ...
# 13898               1.0        0.70        0.70        0.68       0.79
# 13899               1.0        0.70        0.70        0.70       0.74
# 13900               2.0        0.70        0.70        0.70       0.70
# 13901               2.0        0.70        0.70        0.70       0.74
# 13902               2.0        0.74        0.70        0.70       0.70
#
#        hum_lag_2  hum_lag_3
# 0           0.81       0.81
# 1           0.81       0.81
# 2           0.81       0.81
# 3           0.80       0.81
# 4           0.80       0.80
# ...          ...        ...
# 13898       0.79       0.83
# 13899       0.79       0.79
# 13900       0.74       0.79
# 13901       0.70       0.74
# 13902       0.74       0.70
#
# [13903 rows x 31 columns]

# %%
# Step 1: Define the Optuna objective with TimeSeriesSplit on x_train
def objective(trial):
    np.random.seed(42)
    params = {
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.2),
        "depth": trial.suggest_int("depth", 3, 8),
        "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 0.5, 5),
        "iterations": 1000,
        "loss_function": "RMSE",
        "verbose": 0
    }

    train_idx = int(0.85 * x_train.shape[0])

    x_tr, x_val = x_train.iloc[:train_idx], x_train.iloc[train_idx:]
    y_tr, y_val = y_train.iloc[:train_idx], y_train.iloc[train_idx:]

    model = CatBoostRegressor(**params, random_seed=42)
    model.fit(x_tr, y_tr,
              eval_set=(x_val, y_val),
              early_stopping_rounds=100,
              use_best_model=True)

    preds = model.predict(x_val)
    rmse = np.sqrt(mean_squared_error(y_val, preds))

    # Save best iteration
    trial.set_user_attr("best_iteration", model.get_best_iteration())

    return rmse

# %%
# Step 2: Run the Optuna study
study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=150)

# Step 4: Train final model on full x_train with best parameters
best_params = study.best_trial.params
# Out:
# [I 2025-12-12 13:13:17,375] A new study created in memory with name: no-name-23eed229-a40a-4533-9d43-f8b3780aadba
# [I 2025-12-12 13:13:23,320] Trial 0 finished with value: 58.81042883240889 and parameters: {'learning_rate': 0.08116262258099886, 'depth': 8, 'l2_leaf_reg': 3.793972738151323}. Best is trial 0 with value: 58.81042883240889.
# [I 2025-12-12 13:13:25,570] Trial 1 finished with value: 53.899954985643085 and parameters: {'learning_rate': 0.12374511199743694, 'depth': 3, 'l2_leaf_reg': 1.201975341512912}. Best is trial 1 with value: 53.899954985643085.
# [I 2025-12-12 13:13:37,986] Trial 2 finished with value: 58.490011387089496 and parameters: {'learning_rate': 0.021035886311957897, 'depth': 8, 'l2_leaf_reg': 3.20501755284444}. Best is trial 1 with value: 53.899954985643085.
# [I 2025-12-12 13:13:40,379] Trial 3 finished with value: 54.52022048390632 and parameters: {'learning_rate': 0.14453378978124864, 'depth': 3, 'l2_leaf_reg': 4.864594334728975}. Best is trial 1 with value: 53.899954985643085.
# [I 2025-12-12 13:13:43,117] Trial 4 finished with value: 56.33945835163443 and parameters: {'learning_rate': 0.16816410175208013, 'depth': 4, 'l2_leaf_reg': 1.318212352431953}. Best is trial 1 with value: 53.899954985643085.
# [I 2025-12-12 13:13:47,800] Trial 5 finished with value: 55.46946166367573 and parameters: {'learning_rate': 0.044846856872152424, 'depth': 4, 'l2_leaf_reg': 2.86140394234507}. Best is trial 1 with value: 53.899954985643085.
# [I 2025-12-12 13:13:50,370] Trial 6 finished with value: 53.73282972129847 and parameters: {'learning_rate': 0.092069553542002, 'depth': 4, 'l2_leaf_reg': 3.2533380262507077}. Best is trial 6 with value: 53.73282972129847.
# [I 2025-12-12 13:13:55,229] Trial 7 finished with value: 55.5374737018217 and parameters: {'learning_rate': 0.036503833523887946, 'depth': 4, 'l2_leaf_reg': 2.148628294821613}. Best is trial 6 with value: 53.73282972129847.
# [I 2025-12-12 13:13:58,859] Trial 8 finished with value: 54.88381905072201 and parameters: {'learning_rate': 0.09665329700123683, 'depth': 7, 'l2_leaf_reg': 1.3985320197126188}. Best is trial 6 with value: 53.73282972129847.
# [I 2025-12-12 13:14:00,736] Trial 9 finished with value: 56.06831646456435 and parameters: {'learning_rate': 0.1077045432985862, 'depth': 6, 'l2_leaf_reg': 0.7090268572399898}. Best is trial 6 with value: 53.73282972129847.
# [I 2025
. Best is trial 11 with value: 52.503391728487955.
# [I 2025-12-12 13:18:50,942] Trial 106 finished with value: 56.42406999293875 and parameters: {'learning_rate': 0.12098132904759631, 'depth': 3, 'l2_leaf_reg': 0.6841037182243986}. Best is trial 11 with value: 52.503391728487955.
# [I 2025-12-12 13:18:53,204] Trial 107 finished with value: 55.116692658092454 and parameters: {'learning_rate': 0.09871875889618913, 'depth': 4, 'l2_leaf_reg': 1.2451970060468027}. Best is trial 11 with value: 52.503391728487955.
# [I 2025-12-12 13:18:55,340] Trial 108 finished with value: 53.84610591227927 and parameters: {'learning_rate': 0.10675448908535384, 'depth': 3, 'l2_leaf_reg': 0.9661762264492519}. Best is trial 11 with value: 52.503391728487955.
# [I 2025-12-12 13:18:59,242] Trial 109 finished with value: 54.37073978950509 and parameters: {'learning_rate': 0.13123427421367584, 'depth': 4, 'l2_leaf_reg': 1.0434800467318779}. Best is trial 11 with value: 52.503391728487955.
# [I 2025-12-12 13:19:01,793] Trial 110 finished with value: 55.66457427534914 and parameters: {'learning_rate': 0.09187595520314465, 'depth': 5, 'l2_leaf_reg': 1.0619419100154943}. Best is trial 11 with value: 52.503391728487955.
# [I 2025-12-12 13:19:04,551] Trial 111 finished with value: 53.457793600807854 and parameters: {'learning_rate': 0.10366633204761866, 'depth': 3, 'l2_leaf_reg': 1.361543891816328}. Best is trial 11 with value: 52.503391728487955.
# [I 2025-12-12 13:19:06,691] Trial 112 finished with value: 55.95515858238186 and parameters: {'learning_rate': 0.11421199946026137, 'depth': 3, 'l2_leaf_reg': 0.9284650178841978}. Best is trial 11 with value: 52.503391728487955.
# [I 2025-12-12 13:19:09,425] Trial 113 finished with value: 54.20595771155185 and parameters: {'learning_rate': 0.10592736413643253, 'depth': 3, 'l2_leaf_reg': 1.4400911421016935}. Best is trial 11 with value: 52.503391728487955.
# [I 2025-12-12 13:19:13,278] Trial 114 finished with value: 55.34579142756925 and parameters: {'learning_rate': 0.1181900519361974, 'depth': 3, 'l2_leaf_reg': 1.3210493017918572}. Best is trial 11 with value: 52.503391728487955.
# [I 2025-12-12 13:19:16,012] Trial 115 finished with value: 54.93768733421719 and parameters: {'learning_rate': 0.12658682007759534, 'depth': 3, 'l2_leaf_reg': 1.7077062201615698}. Best is trial 11 with value: 52.503391728487955.
# [I 2025-12-12 13:19:18,283] Trial 116 finished with value: 54.86650641167174 and parameters: {'learning_rate': 0.11073355190593778, 'depth': 3, 'l2_leaf_reg': 1.6126436710510228}. Best is trial 11 with value: 52.503391728487955.
# [I 2025-12-12 13:19:20,988] Trial 117 finished with value: 52.645110384847236 and parameters: {'learning_rate': 0.10081728899195397, 'depth': 3, 'l2_leaf_reg': 1.1383846480574284}. Best is trial 11 with value: 52.503391728487955.
# [I 2025-12-12 13:19:25,333] Trial 118 finished with value: 53.18782541086496 and parameters: {'learning_rate': 0.09731772282280776, 'depth': 3, 'l2_leaf_reg': 1.1242670711433955}. Best is trial 11 with value: 52.503391728487955.
# [I 2025-12-12 13:19:28,042] Trial 119 finished with value: 54.23117710809143 and parameters: {'learning_rate': 0.09486010654578202, 'depth': 3, 'l2_leaf_reg': 1.0973611282944582}. Best is trial 11 with value: 52.503391728487955.
# [I 2025-12-12 13:19:30,723] Trial 120 finished with value: 52.363896412172814 and parameters: {'learning_rate': 0.10122693396432887, 'depth': 3, 'l2_leaf_reg': 1.324874758318062}. Best is trial 120 with value: 52.363896412172814.
# [I 2025-12-12 13:19:33,438] Trial 121 finished with value: 53.73516992217841 and parameters: {'learning_rate': 0.09935154314225383, 'depth': 3, 'l2_leaf_reg': 1.330942458197517}. Best is trial 120 with value: 52.363896412172814.
# [I 2025-12-12 13:19:37,840] Trial 122 finished with value: 55.45965282045854 and parameters: {'learning_rate': 0.08847142057190191, 'depth': 3, 'l2_leaf_reg': 1.3537067210889098}. Best is trial 120 with value: 52.363896412172814.
# [I 2025-12-12 13:19:40,602] Trial 123 finished with value: 52.6595092552849 and parameters: {'learning_rate': 0.10098582228379825, 'depth': 3, 'l2_leaf_reg': 1.1917415234795172}. Best is trial 120 with value: 52.363896412172814.
# [I 2025-12-12 13:19:42,635] Trial 124 finished with value: 57.06393731613529 and parameters: {'learning_rate': 0.10302547489664143, 'depth': 3, 'l2_leaf_reg': 1.5519068897198005}. Best is trial 120 with value: 52.363896412172814.
# [I 2025-12-12 13:19:45,311] Trial 125 finished with value: 53.5599485352895 and parameters: {'learning_rate': 0.09813509385079883, 'depth': 3, 'l2_leaf_reg': 1.1419882389053855}. Best is trial 120 with value: 52.363896412172814.
# [I 2025-12-12 13:19:48,543] Trial 126 finished with value: 53.49117216817573 and parameters: {'learning_rate': 0.09933147487755545, 'depth': 3, 'l2_leaf_reg': 1.1527898586341105}. Best is trial 120 with value: 52.363896412172814.
# [I 2025-12-12 13:19:52,342] Trial 127 finished with value: 54.954603563436265 and parameters: {'learning_rate': 0.09856162706837884, 'depth': 3, 'l2_leaf_reg': 1.2636758197642501}. Best is trial 120 with value: 52.363896412172814.
# [I 2025-12-12 13:19:55,030] Trial 128 finished with value: 54.497716839478926 and parameters: {'learning_rate': 0.08536364586254161, 'depth': 3, 'l2_leaf_reg': 1.1369859993902982}. Best is trial 120 with value: 52.363896412172814.
# [I 2025-12-12 13:19:57,733] Trial 129 finished with value: 54.02906864415366 and parameters: {'learning_rate': 0.09252714484985679, 'depth': 3, 'l2_leaf_reg': 1.3981129579743419}. Best is trial 120 with value: 52.363896412172814.
# [I 2025-12-12 13:20:00,425] Trial 130 finished with value: 52.92900710946983 and parameters: {'learning_rate': 0.10094900850678717, 'depth': 3, 'l2_leaf_reg': 0.8165743549073656}. Best is trial 120 with value: 52.363896412172814.
# [I 2025-12-12 13:20:04,823] Trial 131 finished with value: 53.89364924452878 and parameters: {'learning_rate': 0.10017552174441965, 'depth': 3, 'l2_leaf_reg': 0.6393961576128604}. Best is trial 120 with value: 52.363896412172814.
# [I 2025-12-12 13:20:07,337] Trial 132 finished with value: 54.72746469408272 and parameters: {'learning_rate': 0.09537662404287701, 'depth': 3, 'l2_leaf_reg': 0.8629634246257254}. Best is trial 120 with value: 52.363896412172814.
# [I 2025-12-12 13:20:10,167] Trial 133 finished with value: 55.54262827878082 and parameters: {'learning_rate': 0.08916916799438093, 'depth': 3, 'l2_leaf_reg': 1.1742552760737481}. Best is trial 120 with value: 52.363896412172814.
# [I 2025-12-12 13:20:12,940] Trial 134 finished with value: 54.485525200528684 and parameters: {'learning_rate': 0.07968064497729763, 'depth': 3, 'l2_leaf_reg': 0.8350349256112247}. Best is trial 120 with value: 52.363896412172814.
# [I 2025-12-12 13:20:17,298] Trial 135 finished with value: 53.89275418994067 and parameters: {'learning_rate': 0.09829546828304889, 'depth': 3, 'l2_leaf_reg': 0.7498294341649958}. Best is trial 120 with value: 52.363896412172814.
# [I 2025-12-12 13:20:19,652] Trial 136 finished with value: 55.40845669156864 and parameters: {'learning_rate': 0.09559102540772077, 'depth': 3, 'l2_leaf_reg': 0.6043464262281361}. Best is trial 120 with value: 52.363896412172814.
# [I 2025-12-12 13:20:22,121] Trial 137 finished with value: 53.743490283199144 and parameters: {'learning_rate': 0.10101348715656712, 'depth': 3, 'l2_leaf_reg': 1.7945161466422728}. Best is trial 120 with value: 52.363896412172814.
# [I 2025-12-12 13:20:24,832] Trial 138 finished with value: 53.40436847684363 and parameters: {'learning_rate': 0.10419549829684532, 'depth': 3, 'l2_leaf_reg': 0.9760740116738524}. Best is trial 120 with value: 52.363896412172814.
# [I 2025-12-12 13:20:29,016] Trial 139 finished with value: 55.13000987896633 and parameters: {'learning_rate': 0.10472974463840289, 'depth': 3, 'l2_leaf_reg': 0.9574479460810903}. Best is trial 120 with value: 52.363896412172814.
# [I 2025-12-12 13:20:31,709] Trial 140 finished with value: 54.06082712436085 and parameters: {'learning_rate': 0.09167526290527328, 'depth': 3, 'l2_leaf_reg': 0.7163977927006002}. Best is trial 120 with value: 52.363896412172814.
# [I 2025-12-12 13:20:34,436] Trial 141 finished with value: 54.62953088230671 and parameters: {'learning_rate': 0.10229366946057913, 'depth': 3, 'l2_leaf_reg': 1.2084317890972307}. Best is trial 120 with value: 52.363896412172814.
# [I 2025-12-12 13:20:37,207] Trial 142 finished with value: 55.0122278212369 and parameters: {'learning_rate': 0.10818650700219308, 'depth': 3, 'l2_leaf_reg': 1.0026518830666518}. Best is trial 120 with value: 52.363896412172814.
# [I 2025-12-12 13:20:41,565] Trial 143 finished with value: 54.01596501193082 and parameters: {'learning_rate': 0.09834453065467962, 'depth': 3, 'l2_leaf_reg': 1.2891644215978422}. Best is trial 120 with value: 52.363896412172814.
# [I 2025-12-12 13:20:44,258] Trial 144 finished with value: 54.81495884768468 and parameters: {'learning_rate': 0.08209356643470216, 'depth': 3, 'l2_leaf_reg': 1.5341405687656102}. Best is trial 120 with value: 52.363896412172814.
# [I 2025-12-12 13:20:46,901] Trial 145 finished with value: 54.46815125795296 and parameters: {'learning_rate': 0.08906875850734237, 'depth': 3, 'l2_leaf_reg': 1.1252394172748656}. Best is trial 120 with value: 52.363896412172814.
# [I 2025-12-12 13:20:49,500] Trial 146 finished with value: 55.760280931255885 and parameters: {'learning_rate': 0.10318203882221375, 'depth': 3, 'l2_leaf_reg': 0.5347925724146422}. Best is trial 120 with value: 52.363896412172814.
# [I 2025-12-12 13:20:53,830] Trial 147 finished with value: 54.783896164562805 and parameters: {'learning_rate': 0.09468409848245447, 'depth': 3, 'l2_leaf_reg': 0.8887965875370468}. Best is trial 120 with value: 52.363896412172814.
# [I 2025-12-12 13:20:56,404] Trial 148 finished with value: 55.9348861492055 and parameters: {'learning_rate': 0.11003863878280151, 'depth': 3, 'l2_leaf_reg': 1.3214746882368553}. Best is trial 120 with value: 52.363896412172814.
# [I 2025-12-12 13:20:59,111] Trial 149 finished with value: 54.43343991758738 and parameters: {'learning_rate': 0.08647697220611049, 'depth': 3, 'l2_leaf_reg': 0.9929573615393346}. Best is trial 120 with value: 52.363896412172814.

# %%
best_trial = study.best_trial
print("Best RMSE:", best_trial.value)
print("Best iteration (trees):", best_trial.user_attrs["best_iteration"])
# Out:
# Best RMSE: 52.363896412172814
# Best iteration (trees): 884

# %%
best_params.update({
    "iterations": best_trial.user_attrs["best_iteration"],
    "loss_function": "RMSE",
    "verbose": 0
})

# %%
final_model = CatBoostRegressor(**best_params)
final_model.fit(x_train, y_train)

# %% [markdown]
# ## Inference

# %%
# Step 5: Predict on x_test and evaluate
y_pred = final_model.predict(x_test)

# %% [markdown]
# ## Postprocessing

# %%
metrics_catbost = compute_metrics(y_test.values, y_pred)
metrics_catbost
# Out:
# {'MAE': 32.3, 'RMSE': 2523.6, 'MAPE': np.float64(25.56)}

# %%
print('Baseline model scores:', metrics_base)
print('Baseline model with target lags scores:', metrics_target_lag)
print('Baseline model with all lags scores:', metrics_all_lags)
print('Tuned Catboost:', metrics_catbost)
# Out:
# Baseline model scores: {'MAE': 85.33, 'RMSE': 15227.77, 'MAPE': np.float64(38.83)}
# Baseline model with target lags scores: {'MAE': 32.34, 'RMSE': 3019.01, 'MAPE': np.float64(22.64)}
# Baseline model with all lags scores: {'MAE': 32.3, 'RMSE': 3039.02, 'MAPE': np.float64(22.36)}
# Tuned Catboost: {'MAE': 32.3, 'RMSE': 2523.6, 'MAPE': np.float64(25.56)}

# %%
best_params
# Out:
# {'learning_rate': 0.10122693396432887,
#  'depth': 3,
#  'l2_leaf_reg': 1.324874758318062,
#  'iterations': 884,
#  'loss_function': 'RMSE',
#  'verbose': 0}

# %%
# Save the model to experiments
final_model.save_model('./models/experiments/final_catboost_model.cbm')

# %% [markdown]
# - We see that we are able to reduce the RMSE score and MAE score quite well.
# - MAPE score has not been reduced. However, since we have quite many values close to zero, MAPE is not a good metric in this case.
# - Note that in Bayesian Optiization we optimized for RMSE, we can also try to optimize for MAE.

# %% [markdown]
# # Conclusions

# %% [markdown]
# - The Baseline Random Foreset model with no feature engineering gave almost the same result as the dummy model (last value shifted forward)
# - Adding the target lags and feature lags improved the model significantly,
# - Changing Random Forest to Catboost and tuning Catboost Hyperparameters with Bayesian Optimization helped futher improve the scores.
# - For the production pipeline, we will use Catboost Model with Hyperparameter tuning.
